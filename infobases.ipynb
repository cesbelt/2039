# %% [markdown]
# # Welcome to an example Binder

# %% [markdown]
# We need `seaborn`, which shall be included it in `requirements.txt` file

# %%
import pandas as pd

# %%
datas = 'datasets/weight-height.csv'
df = pd.read_csv(datas)

# %%
df
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
datas1 = 'datasets/tips.csv'
df1 = pd.read_csv(datas1)

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
datas2 = 'datasets/sample_pivot.csv'
df2 = pd.read_csv(datas2)

# %%
df2
# Out:
#       Date Region                 Type  Units  Sales
# 0    44023   East  Children's Clothing   18.0    306
# 1    44097  North  Children's Clothing   14.0    448
# 2    43923  South     Women's Clothing   17.0    425
# 3    43889   East  Children's Clothing   26.0    832
# 4    43909   West     Women's Clothing    3.0     33
# ..     ...    ...                  ...    ...    ...
# 995  43872   East  Children's Clothing   35.0    735
# 996  44190  North       Men's Clothing    NaN   1155
# 997  44074  South       Men's Clothing   13.0    208
# 998  44066  South     Women's Clothing   17.0    493
# 999  44060  North     Women's Clothing   25.0    300
#
# [1000 rows x 5 columns]

# %%
datas3 = 'datasets/pokemon.csv'
df3 = pd.read_csv(datas3)

# %%
df3
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
datas4 = 'datasets/nhanes_2015_2016.csv'
df4 = pd.read_csv(datas4)

# %%
df4
# Out:
#        SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0     83732     1.0     NaN     1.0       1         1        62         3
# 1     83733     1.0     NaN     6.0       1         1        53         3
# 2     83734     1.0     NaN     NaN       1         1        78         3
# 3     83735     2.0     1.0     1.0       2         2        56         3
# 4     83736     2.0     1.0     1.0       2         2        42         4
# ...     ...     ...     ...     ...     ...       ...       ...       ...
# 5730  93695     2.0     2.0     NaN       1         2        76         3
# 5731  93696     2.0     2.0     NaN       2         1        26         3
# 5732  93697     1.0     NaN     1.0       1         2        80         3
# 5733  93700     NaN     NaN     NaN       1         1        35         3
# 5734  93702     1.0     NaN     2.0       2         2        24         3
#
#       DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# ...

# %%
datas5 = 'datasets/headbrain.csv'
df5 = pd.read_csv(datas5)

# %%
df5
# Out:
#      Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0         1          1             4512                 1530
# 1         1          1             3738                 1297
# 2         1          1             4261                 1335
# 3         1          1             3777                 1282
# 4         1          1             4177                 1590
# ..      ...        ...              ...                  ...
# 232       2          2             3214                 1110
# 233       2          2             3394                 1215
# 234       2          2             3233                 1104
# 235       2          2             3352                 1170
# 236       2          2             3391                 1120
#
# [237 rows x 4 columns]

# %%
datas6 = 'datasets/data.csv'
df6 = pd.read_csv(datas6)

# %%
df6
# Out:
#     32.502345269453031  31.70700584656992
# 0            53.426804          68.777596
# 1            61.530358          62.562382
# 2            47.475640          71.546632
# 3            59.813208          87.230925
# 4            55.142188          78.211518
# ..                 ...                ...
# 94           50.030174          81.536991
# 95           49.239765          72.111832
# 96           50.039576          85.232007
# 97           48.149859          66.224958
# 98           25.128485          53.454394
#
# [99 rows x 2 columns]

# %%
datas7 = 'datasets/cwurData.csv'
df7 = pd.read_csv(datas7)

# %%
df7
# Out:
#       world_rank                            institution         country  \
# 0              1                     Harvard University             USA
# 1              2  Massachusetts Institute of Technology             USA
# 2              3                    Stanford University             USA
# 3              4                University of Cambridge  United Kingdom
# 4              5     California Institute of Technology             USA
# ...          ...                                    ...             ...
# 2195         996              University of the Algarve        Portugal
# 2196         997                  Alexandria University           Egypt
# 2197         998            Federal University of Ceará          Brazil
# 2198         999                 University of A Coruña           Spain
# 2199        1000        China Pharmaceutical University           China
#
#       national_rank  quality_of_education  alumni_employment  \
# ...

# %%
datas8 = 'datasets/census.csv'
df8 = pd.read_csv(datas8)
df8
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         40       3         6      1       0  Alabama            Alabama
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3189      50       4         8     56      39  Wyoming       Teton County
# 3190      50       4         8     56      41  Wyoming       Uinta County
# 3191      50       4         8     56      43  Wyoming    Washakie County
# 3192      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %%
datas9 = 'datasets/antropometria00.csv'
df9 = pd.read_csv(datas9)
df9
# Out:
#     folio  intp  entidad          desc_ent  sexo  edad  meses   peso  ropa  \
# 0  101655     3       10           DURANGO     2    11     11  35.65     2
# 1   91526     4        9  DISTRITO FEDERAL     1    10      8  33.40     2
# 2  241555     3       24   SAN LUIS POTOSI     1    10      7  31.90     1
# 3  211879     2       21            PUEBLA     2    10      9  31.95     2
# 4   80135     3        8         CHIHUAHUA     2    11      9  32.40     1
#
#     talla  ... hpresion tbrazo  htension  PrimaryLast  code_upm  est_dis  \
# 0  145.10  ...    15:25      3     15:25            1     M1041        1
# 1  146.50  ...     7:40      3      7:45            1     M0931        4
# 2  141.45  ...    20:12      1     20:19            1     M2435        5
# 3  134.95  ...    22:22      2     15:11            1     M2144        1
# 4  136.60  ...    18:32      3     18:32            1     M0804        7
#
#   est_urb  est_marg       pondef  est_var
# ...

# %%
datas10 = 'datasets/antropometria-dataset.csv'
df10 = pd.read_csv(datas10)
df10
# Out:
#         folio  intp  entidad                         desc_ent  sexo  edad  \
# 0      210295     2       21                           PUEBLA     2    38
# 1      101655     3       10                          DURANGO     2    11
# 2       10287     6        1                   AGUASCALIENTES     2    18
# 3       91526     4        9                 DISTRITO FEDERAL     1    10
# 4      210939     3       21                           PUEBLA     2    19
# ...       ...   ...      ...                              ...   ...   ...
# 18635  300116     2       30  VERACRUZ DE IGNACIO DE LA LLAVE     2    73
# 18636   40253     1        4                         CAMPECHE     2    75
# 18637  301099     1       30  VERACRUZ DE IGNACIO DE LA LLAVE     1    86
# 18638  250801     1       25                          SINALOA     2    72
# 18639   11786     2        1                   AGUASCALIENTES     2    71
#
#        meses   peso  ropa   talla  ... hpresion tbrazo  htension  PrimaryLast  \
# ...

# %%
datas11 = 'datasets/airline_data.csv'
df11 = pd.read_csv(datas11)
df11
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3166: DtypeWarning: Columns (70,77) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       Unnamed: 0  Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0        1295781  1998        2      4           2          4  1998-04-02
# 1        1125375  2013        2      5          13          1  2013-05-13
# 2         118824  1993        3      9          25          6  1993-09-25
# 3         634825  1994        4     11          12          6  1994-11-12
# 4        1888125  2017        3      8          17          4  2017-08-17
# ...          ...   ...      ...    ...         ...        ...         ...
# 9437     1088659  1999        1      1          27          3  1999-01-27
# 9438      605975  2008        1      3          24          1  2008-03-24
# ...

# %%
datas12 = 'datasets/adult.csv'
df12 = pd.read_csv(datas12)
df12
# Out:
#        age          workclass  fnlwgt   education  education-num  \
# 0       39          State-gov   77516   Bachelors             13
# 1       50   Self-emp-not-inc   83311   Bachelors             13
# 2       38            Private  215646     HS-grad              9
# 3       53            Private  234721        11th              7
# 4       28            Private  338409   Bachelors             13
# ...    ...                ...     ...         ...            ...
# 32559   22            Private  201490     HS-grad              9
# 32560   52       Self-emp-inc  287927     HS-grad              9
# 32561   52       Self-emp-inc  287927     HS-grad              9
# 32562   52       Self-emp-inc  287927     HS-grad              9
# 32563   52       Self-emp-inc  287927     HS-grad              9
#
#               marital-status          occupation    relationship    race  \
# 0              Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
datas13 = 'datasets/Cartwheeldata.csv'
df13 = pd.read_csv(datas13)
df13
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0    1   56      F            1       Y             1   62.00      61.0
# 1    2   26      F            1       Y             1   62.00      60.0
# 2    3   33      F            1       Y             1   66.00      64.0
# 3    4   39      F            1       N             0   64.00      63.0
# 4    5   27      M            2       N             0   73.00      75.0
# 5    6   24      M            2       N             0   75.00      71.0
# 6    7   28      M            2       N             0   75.00      76.0
# 7    8   22      F            1       N             0   65.00      62.0
# 8    9   29      M            2       Y             1   74.00      73.0
# 9   10   33      F            1       Y             1   63.00      60.0
# 10  11   30      M            2       Y             1   69.50      66.0
# 11  12   28      F            1       Y             1   62.75      58.0
# ...
